# %% [markdown]
# Accuracy:
# - Underfitted Model -> *Training is not good*
# - Overfitted Model -> *Training is Good* but *Testing is not Good*
# - Bestfit Model -> *Trainig is Good* and *Testing is Good*

# %% [markdown]
# ![image.png](attachment:caac31e4-b112-48e3-96f2-69f5ae2219a4.png)

# %% [markdown]
# | Accuracy | Training | Testing | Model Type     | Bias       | Variance   |
# |----------|----------|---------|----------------|------------|------------|
# |          | < 80%    | < 80%   | Underfit       | High       | High       |
# |          | > 90%    | < 80%   | Overfit Model  | Low        | High       |
# |          | > 90%    | > 90%   | Best Fit       | Low        | Low        |
#
#
#
#
# Bias and Variance
#  - Bias : Testing Error
#  - Variance: Testing Error

# %% [markdown]
# **Bias Variance TradeOff**
